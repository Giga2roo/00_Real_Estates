# %%
# %pip install xlwings
# Out:
# Requirement already satisfied: xlwings in /Users/krc/miniforge3/lib/python3.9/site-packages (0.27.10)
# Requirement already satisfied: appscript>=1.0.1 in /Users/krc/miniforge3/lib/python3.9/site-packages (from xlwings) (1.2.0)
# Requirement already satisfied: psutil>=2.0.0 in /Users/krc/miniforge3/lib/python3.9/site-packages (from xlwings) (5.9.0)
# Requirement already satisfied: lxml>=4.7.1 in /Users/krc/miniforge3/lib/python3.9/site-packages (from appscript>=1.0.1->xlwings) (4.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import xlwings as xw

path = r'data/202206_월간시계열.xlsx'
#sheet = pd.read_excel(path, sheet_name='1.매매종합')

wb = xw.Book(path)
sheet = wb.sheets['1.매매종합']
row_num = sheet.range((1,1)).end('down').end('down').end('down').row
data_range = 'A2:GE' + str(row_num)
raw_data = sheet[data_range].options(pd.DataFrame, index=False, header=True).value

# %%
raw_data
# Out:
#                  구분          전국          서울        강북\n14개구        None  \
# 0              None        None        None            None         강북구
# 1    Classification       Total       Seoul  Northern seoul  Gangbuk-gu
# 2              86.1    27.68215   23.472864       32.594416        None
# 3               2.0    27.68215   23.472864       32.554907        None
# 4               3.0   27.723591   23.440488       32.554907        None
# ..              ...         ...         ...             ...         ...
# 435             2.0  100.207368  100.196351      100.249743  100.044046
# 436             3.0  100.305605  100.252724      100.278068  100.045391
# 437             4.0  100.516504  100.379697      100.346183  100.079498
# 438             5.0  100.768293  100.557572      100.514011  100.107569
# 439             6.0  100.868527  100.723141      100.673584  100.170506
#
#             None        None        None           None        None  ...  \
# 0            광진구         노원구         도봉구           동대문구         마포구  ...
# 1    Gwangjin-gu    Nowon-gu   Dobong-gu  Dongdaemun-gu     Mapo-gu  ...
# 2           None        None        None           None        None  ...
# 3           None        None        None           None        None  ...
# 4           None        None        None           None        None  ...
# ..           ...         ...         ...            ...         ...  ...
# 435    100.39913  100.045036  100.454603      99.992477  100.038371  ...
# 436   100.426325  100.040477  100.573273      99.956221  100.070985  ...
# 437   100.736142  100.054681  100.662162     100.063984  100.105513  ...
# 438    101.29182  100.025793  100.833792     100.220039  100.240308  ...
# 439   101.431506   99.931069  100.927532     100.279169  100.498788  ...
#
#            None        None       양산     거제          진주          김해  \
# 0           의창구         진해구     None   None        None        None
# 1       Uichang      Jinhae  Yangsan  Geoje       Jinju      Gimhae
# 2          None        None     None   None        None        None
# 3          None        None     None   None        None        None
# 4          None        None     None   None        None        None
# ..          ...         ...      ...    ...         ...         ...
# 435  100.287111  100.317359     None   None  100.502209  100.183431
# 436  100.425939  100.501761     None   None  101.072266  100.148233
# 437  100.854237  101.201873     None   None  101.461046  100.124852
# 438   101.60097  102.027125     None   None  102.017169  100.116237
# 439  102.668235  102.383504     None   None  102.557368  100.108882
#
#             통영       제주도         제주/\n서귀포                   기타지방
# 0         None      None             None                   None
# 1    Tongyoung  Jeju-do   Jeju/\nSeogwipo  Non-Metropolitan Area
# 2         None      None             None                   None
# 3         None      None             None                   None
# 4         None      None             None                   None
# ..         ...       ...              ...                    ...
# 435       None      None        100.28025             100.308473
# 436       None      None       100.403816             100.536559
# 437       None      None        100.55995             100.874314
# 438       None      None       100.949068             101.267352
# 439       None      None       101.229909             101.491416
#
# [440 rows x 187 columns]

# %%
sheet.range
# Out:
# <bound method Sheet.range of <Sheet [202206_월간시계열.xlsx]1.매매종합>>

# %%
bignames = '서울 대구 부산 대전 광주 인천 울산 세종 경기 강원 충북 충남 전북 전남 경북 경남 제주도 6개광역시 5개광역시 수도권 기타지방 구분 전국'
bigname_list = bignames.split(' ')
big_col = list(raw_data.columns)
small_col = list(raw_data.iloc[0])

# %%
for num, gu_data in enumerate(small_col):
    if gu_data == None:
        small_col[num] = big_col[num]
        
        check = num
        while True:
            if big_col[check] in bigname_list:
                big_col[num] = big_col[check]
                break
            else:
                check = check - 1

# %%
test_col = pd.DataFrame({'small_col':small_col, 'big_col':big_col})

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
test_col
# Out:
#         small_col big_col
# 0              구분      구분
# 1              전국      전국
# 2              서울      서울
# 3        강북\n14개구      서울
# 4             강북구    None
# 5             광진구    None
# 6             노원구    None
# 7             도봉구    None
# 8            동대문구    None
# 9             마포구    None
# 10           서대문구    None
# 11            성동구    None
# 12            성북구    None
# 13            용산구    None
# 14            은평구    None
# 15            종로구    None
# 16             중구    None
# 17            중랑구    None
# 18       강남\n11개구      서울
# 19            강남구    None
# 20            강동구    None
# 21            강서구    None
# 22            관악구    None
# 23            구로구    None
# 24            금천구    None
# 25            동작구    None
# 26            서초구    None
# 27            송파구    None
# 28            양천구    None
# 29           영등포구    None
# 30          6개광역시   6개광역시
# 31             부산      부산
# 32             중구    None
# 33             서구    None
# 34             동구    None
# 35            영도구    None
# 36           부산진구    None
# 37            동래구    None
# 38             남구    None
# 39             북구    None
# 40           해운대구    None
# 41            사하구    None
# 42            금정구    None
# 43            연제구    None
# 44            수영구    None
# 45            사상구    None
# 46            기장군    None
# 47            강서구    None
# 48             대구      대구
# 49             중구    None
# 50             동구    None
# 51             서구    None
# 52             남구    None
# 53             북구    None
# 54            수성구    None
# 55            달서구    None
# 56            달성군    None
# 57             인천      인천
# 58             중구    None
# 59             동구    None
# 60           미추홀구    None
# 61            연수구    None
# 62            남동구    None
# 63            부평구    None
# 64            계양구    None
# 65             서구    None
# 66             광주      광주
# 67             동구    None
# 68             서구    None
# 69             남구    None
# 70             북구    None
# 71            광산구    None
# 72             대전      대전
# 73             동구    None
# 74             중구    None
# 75             서구    None
# 76            유성구    None
# 77            대덕구    None
# 78             울산      울산
# 79             중구    None
# 80             남구    None
# 81             동구    None
# 82             북구    None
# 83            울주군    None
# 84   5개광역시\n(인천外)      울산
# 85            수도권     수도권
# 86             세종      세종
# 87             경기      경기
# 88             수원      경기
# 89            장안구    None
# 90            권선구    None
# 91            팔달구    None
# 92            영통구    None
# 93             성남      경기
# 94            수정구    None
# 95            중원구    None
# 96            분당구    None
# 97             고양      경기
# 98            덕양구    None
# 99           일산동구    None
# 100          일산서구    None
# 101            안양      경기
# 102           만안구    None
# 103           동안구    None
# 104            부천      경기
# 105           의정부      경기
# 106            광명      경기
# 107            평택      경기
# 108            안산      경기
# 109           단원구    None
# 110           상록구    None
# 111            과천      경기
# 112            구리      경기
# 113           남양주      경기
# 114            용인      경기
# 115           처인구    None
# 116           기흥구    None
# 117           수지구    None
# 118            시흥      경기
# 119            군포      경기
# 120            의왕      경기
# 121            하남      경기
# 122            오산      경기
# 123            파주      경기
# 124            이천      경기
# 125            안성      경기
# 126            김포      경기
# 127            양주      경기
# 128           동두천      경기
# 129            광주      광주
# 130            화성      광주
# 131            강원      강원
# 132            춘천      강원
# 133            강릉    None
# 134            원주      강원
# 135            충북      충북
# 136            청주      충북
# 137           상당구    None
# 138           서원구    None
# 139           청원구    None
# 140           흥덕구    None
# 141            충주      충북
# 142            제천      충북
# 143            충남      충남
# 144            천안      충남
# 145           동남구    None
# 146           서북구    None
# 147            공주      충남
# 148            아산      충남
# 149            논산      충남
# 150            계룡      충남
# 151            당진      충남
# 152            서산      충남
# 153            전북      전북
# 154            전주      전북
# 155           완산구    None
# 156           덕진구    None
# 157            익산      전북
# 158            군산      전북
# 159            전남      전남
# 160            목포      전남
# 161            순천      전남
# 162            광양      전남
# 163            여수      전남
# 164            경북      경북
# 165            포항      경북
# 166            남구    None
# 167            북구    None
# 168            구미      경북
# 169            경산      경북
# 170            안동      경북
# 171            김천      경북
# 172            경남      경남
# 173            창원      경남
# 174         마산합포구    None
# 175         마산회원구    None
# 176           성산구    None
# 177           의창구    None
# 178           진해구    None
# 179            양산      경남
# 180            거제      경남
# 181            진주      경남
# 182            김해      경남
# 183            통영      경남
# 184           제주도     제주도
# 185      제주/\n서귀포     제주도
# 186          기타지방    기타지방

# %%
raw_data.head()
# Out:
#   주택매매가격 종합지수  Housing purchase price composite indices                                                                            (2022.01=100.0)  \
# 0                                                 구분
# 1                                                NaN
# 2                                     Classification
# 3                                               86.1
# 4                                                  2
#
#   Unnamed: 1 Unnamed: 2      Unnamed: 3  Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0         전국         서울        강북\n14개구         NaN          NaN        NaN
# 1        NaN        NaN             NaN         강북구          광진구        노원구
# 2      Total      Seoul  Northern seoul  Gangbuk-gu  Gwangjin-gu   Nowon-gu
# 3   27.68215  23.472864       32.594416         NaN          NaN        NaN
# 4   27.68215  23.472864       32.554907         NaN          NaN        NaN
#
#   Unnamed: 7     Unnamed: 8 Unnamed: 9  ... Unnamed: 178 Unnamed: 179  \
# 0        NaN            NaN        NaN  ...          NaN           양산
# 1        도봉구           동대문구        마포구  ...          진해구          NaN
# 2  Dobong-gu  Dongdaemun-gu    Mapo-gu  ...       Jinhae      Yangsan
# 3        NaN            NaN        NaN  ...          NaN          NaN
# 4        NaN            NaN        NaN  ...          NaN          NaN
#
#   Unnamed: 180 Unnamed: 181 Unnamed: 182 Unnamed: 183 Unnamed: 184  \
# 0           거제           진주           김해           통영          제주도
# 1          NaN          NaN          NaN          NaN          NaN
# 2        Geoje        Jinju       Gimhae    Tongyoung     Jeju-do
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 185           Unnamed: 186 Unnamed: 187
# 0         제주/\n서귀포                   기타지방          NaN
# 1              NaN                    NaN          NaN
# 2  Jeju/\nSeogwipo  Non-Metropolitan Area          NaN
# 3              NaN                    NaN          NaN
# 4              NaN                    NaN          NaN
#
# [5 rows x 188 columns]
